# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasmPRD/Programacao/blob/main/aula_4_13_03_1_C_grupo_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * **ESCREVER UM PROGRAMA QUE RECEBE A TEMPERATURA EM GRAUS CELSIUS E CONVERTE PARA FAHRENHEIT**
#
# # Entrada
#
# graus celsius
#
# # Processamento
#
# F= C * (9/5) + 32
#
# # Saída
#
# mostrar graus em Fahrenheit

# %%
# Escrever um programa que recebe em graus celsius e transforma em fahrenheit

# Entrada

print ("----------------------------TERMÔMETRO CONVERSOR--------------------------------|")
print ( )
Celsius = float (input ("digite a temperatura em graus celsius:"))
print ( )

# Processamento

Fahrenheit = Celsius * (9/5) + 32

# Saída

print ("----------------------------COVERSÃO EM FAHRENHEIT-------------------------------|")
print ( )
print (f"A temperatura é de {Fahrenheit}°F")
# Out:
# ----------------------------TERMÔMETRO CONVERSOR--------------------------------
#
# digite a temperatura em graus celsius:15
#
# ----------------------------COVERSÃO EM FAHRENHEIT--------------------------------
#
# A temperatura é de 59.0°F

# %%
# Calcular area do retângulo

#Entrada

comprimento = float (input ("digite o comprimento:"))
altura = float (input ("digite a altura:"))


#Processamento

area = comprimento * altura

#Saída

print (f"o total da área do retangulo é igual:{area} ")
# Out:
# digite o comprimento:20
# digite a altura:10
# o total da área do retangulo é igual:200.0

# %%
# Escreva um programa que soma dois números

# Entrada

a = float (input ("digite o primeiro número: "))
b = float (input ("digite o segundo número: "))

# Processamento

soma = a + b
subtraçao = a - b
multiplicaçao = a * b
divisao = a / b
div_int = a // b # usar barras duplas "//" para aproximação/divisões inteiras
resto = a % b #o símbolo de "%" é igual ao resto da divisão

# Saída


print ("--------------------CALCULADORA SIMPLES------------------- |")
print ("                                                           |")
print ("---------------------------soma--------------------------- |")
print ("                                                           |")
print (f"a soma de {a} mais {b} é igual: {soma} ")
print ("                                                           |")
print ("-------------------------subtração------------------------ |")
print ("                                                           |")
print (f"a subtração de {a} menos {b} é igual: {subtraçao} ")
print ("                                                           |")
print ("-----------------------multiplicação---------------------- |")
print ("                                                           |")
print (f"a multiplicação de {a} vezes {b} é igual: {multiplicaçao}")
print ("                                                           |")
print ("--------------------------divisão------------------------- |")
print ("                                                           |")
print (f"a divisão de {a} dividido por {b} é igual: {divisao}")
print ("                                                           |")
print ("----------------------divisão aproximada------------------ |")
print ("                                                           |")
print (f"a divisão aproximada de {a} dividido por {b} é igual: {div_int}")
print ("                                                           |")
print ("-----------------------------resto------------------------ |")
print ("                                                           |")
print (f"o resto de {a} dividido por {b} é igual: {resto}")
print ("                                                           |")
print ("---------------------------------------------------------- |")
# Out:
# digite o primeiro número: 7
# digite o segundo número: 8
# --------------------CALCULADORA SIMPLES------------------- |
#                                                            |
# ---------------------------soma--------------------------- |
#                                                            |
# a soma de 7.0 mais 8.0 é igual: 15.0
#                                                            |
# -------------------------subtração------------------------ |
#                                                            |
# a subtração de 7.0 menos 8.0 é igual: -1.0
#                                                            |
# -----------------------multiplicação---------------------- |
#                                                            |
# a multiplicação de 7.0 vezes 8.0 é igual: 56.0
#                                                            |
# --------------------------divisão------------------------- |
# ...

# %%
# Escrever um programa que subtraía dois números

# Entrada

c = int (input ("digite o primeiro número: "))
d = int (input ("digite o segundo número: "))

# Processamento

subtração = c - d

# Saída

print (f"o resultado da subtração de {c} menos {d} é igual : {subtração}")
# Out:
# digite o primeiro número: 34
# digite o segundo número: 12
# o resultado da subtração de 34 menos 12 é igual : 22
