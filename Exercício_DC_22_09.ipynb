# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasmPRD/Programacao/blob/main/Exerc%C3%ADcio_DC_22_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Crie um dicionário chamado aluno contendo: nome, idade e curso. Mostre o
# dicionário.

# %%
aluno = {
    "nome":"Lucas",
    "idade": 15,
    "curso": "Informática"
}
print (aluno)
# Out:
# {'nome': 'Lucas', 'idade': 15, 'curso': 'Informática'}

# %% [markdown]
# 2. Crie um dicionário com nome, idade e curso de um aluno. Mostre cada
# informação separadamente.

# %%
aluno = {
    "nome":"Lucas",
    "idade": 15,
    "curso": "Informática"
}

print (aluno['nome'])
print (aluno['idade'])
print (aluno['curso'])

# %% [markdown]
# 3. Crie um dicionário produto contendo nome, preço e estoque. Altere o preço e
# mostre o resultado

# %%
produto = {
    "nome":"notebook",
    "preço": 1500.00,
    "estoque":15
}

produto['preço'] = 3000.00

print (produto["preço"])
# Out:
# 3000.0

# %% [markdown]
# 4. Crie um dicionário aluno contendo nome e idade. Depois, adicione a
# informação curso.

# %%
aluno = {
    "nome": "Lucas",
    "idade": 20

}

aluno['curso'] = "Administração"

print (aluno)
# Out:
# {'nome': 'Lucas', 'idade': 20, 'curso': 'Administração'}

# %% [markdown]
# 5. Crie um dicionário chamado filme contendo: título, ano, gênero e nota. Depois,
# mostre cada informação separadamente.

# %%
filme = {
    "titulo": "Interestelar",
    "ano": 2020,
    "genero": "ficção científica",
    "nota": 10/10
}

print (filme["titulo"])
print (filme["ano"])
print (filme["genero"])
print (filme["nota"])
# Out:
# Interestelar
# 2020
# ficção científica
# 1.0

# %% [markdown]
# 1. Crie um conjunto chamado numeros contendo os números de 1 a 5. Mostre o
# conjunto.

# %%
numeros = {
    1,2,3,4,5
    }
print (numeros)

# %% [markdown]
# 2. Crie numeros = {1, 2, 2, 3, 3, 3, 4, 5}. Mostre o conjunto e observe o que
# acontece com os números repetidos.

# %%
numeros = {
    1, 2, 2, 3, 3, 3, 4, 5
    }
print (numeros)
#Eles não aparecem, o phyton exclui repetição
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 3. Crie frutas = {"maçã", "banana", "laranja"}. Adicione "morango" usando add().

# %%
frutas = {
    "maçã", "banana", "laranja"
    }
frutas.add("morango")
print (frutas)
# Out:
# {'laranja', 'morango', 'maçã', 'banana'}

# %% [markdown]
# 4. Crie cores = {"vermelho", "azul", "verde", "amarelo"}. Remova "verde" usando
# remove().

# %%
cores = {
    "vermelho", "azul", "verde", "amarelo"
    }
cores.remove("verde")
print (cores)
# Out:
# {'amarelo', 'azul', 'vermelho'}

# %% [markdown]
# 5. Crie a lista: nomes = ["Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi",
# “Gael",”Theo”, “Theo”]
# Transforme a lista em um conjunto para eliminar os nomes repetidos.

# %%
nomes = ["Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi", "Gael","Theo", "Theo"]
nomes = {
    "Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi", "Gael", "Theo", "Theo"
    }

print (nomes)
# Out:
# {'Ravi', 'Yris', 'Gael', 'Maitê', 'Luna', 'Theo'}
