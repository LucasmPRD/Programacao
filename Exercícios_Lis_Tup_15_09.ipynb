# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasmPRD/Programacao/blob/main/Exerc%C3%ADcios_Lis_Tup_15_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.	Crie uma lista chamada frutas contendo: maçã, banana, laranja e morango. Mostre a lista.

# %%
frutas = ["Maçã", "Banana", "Laranja", "Morango"]
print (frutas)
# Out:
# ['Maçã', 'Banana', 'Laranja', 'Morango']

# %% [markdown]
# 2.	Crie a lista nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]. Mostre o primeiro, o segundo e o último nome.

# %%
nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]
print (nomes[0], nomes[1], nomes[-1])
# Out:
# Rebeca Guilherme Kyara

# %% [markdown]
# 3.	Crie cores = ["vermelho", "azul", "verde"]. Troque "azul" por "amarelo" e mostre a lista.

# %%
cores = ["vermelho", "azul", "verde"]
cores[1] = "amarelo"
print (cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %% [markdown]
# 4.	Crie alunos = ["Nicolas", "Wendel", "Pyetra"]. Adicione "Petros" usando append().

# %%
alunos = ["Nicolas", "Wendel", "Pyetra"]
alunos.append("Petros")
print (alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %% [markdown]
# 5.	Crie animais = ["cachorro", "gato", "coelho", "passarinho"]. Remova "coelho" usando remove().

# %%
animais = ["cachorro", "gato", "coelho", "passarinho"]
animais.remove("coelho")
print (animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %% [markdown]
# 1.	Crie uma tupla chamada meses contendo Janeiro, Fevereiro, Março e Abril. Mostre a tupla.

# %%
meses = ("Janeiro", "Fevereiro", "Março", "Abril")
print (meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %% [markdown]
# 2.	Crie numeros = (10, 20, 30, 40, 50). Mostre o primeiro, o terceiro e o último número.

# %%
numeros = (10, 20, 30, 40, 50)
print (numeros[0], numeros[2], numeros[-1])
# Out:
# 10 30 50

# %% [markdown]
# 3.	Crie uma tupla aluno contendo o nome, a idade e o curso de um aluno. Mostre cada informação separadamente.

# %%
aluno = ('Murilo', 15, 'Infonet')
print (aluno[1])
print (aluno[0])
print (aluno[2])
# Out:
# 15
# Murilo
# Infonet

# %% [markdown]
# 4.	Crie cores = ("vermelho", "azul", "verde"). Tente alterar "azul" para "amarelo". Observe o que acontece.

# %%
cores = ("vermelho", "azul", "verde")

cores[1] = "amarelo" #Ocorre um erro nessa linha, pois diz que a tupla não suporta esse comando
print (cores)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2977/3253211236.py in <cell line: 0>()
#       1 cores = ("vermelho", "azul", "verde")
#       2
# ----> 3 cores[1] = "amarelo"
#       4 print (cores)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 5.	Crie numeros = (2, 4, 2, 6, 2, 8, 10). Use count() para descobrir quantas vezes o
# número 2 aparece.

# %%
numeros = (2, 4, 2, 6, 2, 8, 10)
print (numeros.count(2))
# Out:
# 3
